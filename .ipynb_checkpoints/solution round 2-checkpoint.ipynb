# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./files_for_lab/csv_files/marketing_customer_analysis.csv")

# %%
# shape of the dataframe
data.shape
# Out:
# (10910, 26)

# %%
# dropping the weird column
try:
    data = data.drop(["Unnamed: 0"], axis = 1)
except:
    pass

# %%
# adding space between words in column name
data = data.rename(columns={'EmploymentStatus':'Employment Status'})

# %%
# lowercase for all column headers
cols = []
for i in data.columns:
    cols.append(i.lower())
data.columns = cols

# %%
# in case we wanna display the dataframe with all the columns
pd.set_option('display.max_columns', None)

# %%
# displaying only columns with numerical values
display(data.select_dtypes(np.number).columns)
print("Total column(s) with numerical values:",len(data.select_dtypes(np.number).columns))
# Out:
# Index(['customer lifetime value', 'income', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies',
#        'total claim amount'],
#       dtype='object')
# Total column(s) with numerical values: 8

# %%
# displaying only columns with categorical values
display(data.select_dtypes(object).columns)
print("Total column(s) with categorical values:",len(data.select_dtypes(object).columns))
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective to date', 'employment status', 'gender', 'location code',
#        'marital status', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')
# Total column(s) with categorical values: 17

# %%
# counting nan
data.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employment status                   0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# dtype: int64

# %%
# displaying percentage of the nan values in the dataframe format, bcs its cool
nulls = pd.DataFrame(round(data.isna().sum()/len(data),4)*100)
nulls = nulls.reset_index()
nulls.columns = ['header_name', 'nulls_in_%']
display(nulls)
# Out:
#                       header_name  nulls_in_%
# 0                        customer        0.00
# 1                           state        5.78
# 2         customer lifetime value        0.00
# 3                        response        5.78
# 4                        coverage        0.00
# 5                       education        0.00
# 6               effective to date        0.00
# 7               employment status        0.00
# 8                          gender        0.00
# 9                          income        0.00
# 10                  location code        0.00
# 11                 marital status        0.00
# 12           monthly premium auto        0.00
# 13        months since last claim        5.80
# 14  months since policy inception        0.00
# 15      number of open complaints        5.80
# 16             number of policies        0.00
# 17                    policy type        0.00
# 18                         policy        0.00
# 19               renew offer type        0.00
# 20                  sales channel        0.00
# 21             total claim amount        0.00
# 22                  vehicle class        5.70
# 23                   vehicle size        5.70
# 24                   vehicle type       50.25

# %%
# checking whether the nan are in the same row: response and state
# prints False if the rows dont match. prints nothing if the rows match

#saving index of the nan values to a variable
# the variables will then be matched
na_response = data[data['response'].isnull()].index.tolist()
na_state = data[data['state'].isnull()].index.tolist()
for i in range(631):
    if na_response[i] != na_state[i]:
        print(False)

# %%
# just counting unique values to find the mode, if theres any
display(data["response"].value_counts(dropna=False))
display(data["state"].value_counts(dropna=False))
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: response, dtype: int64
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64

# %%
# replacing nan values with mode, because adding around 5% to the mode value wont change much
data['state'] = data['state'].fillna("California")
display(data['state'].value_counts(dropna = False))
data['response'] = data['response'].fillna("No")
display(data['response'].value_counts(dropna = False))
# Out:
# California    4183
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: state, dtype: int64
# No     9444
# Yes    1466
# Name: response, dtype: int64

# %%
# in case we want to just delete the rows. but this time i feel like keeping them. see reason above.
# data = data.drop(labels = data[data['response'].isnull()].index.tolist(), axis = 0)

# %%
# looking for duplicates
duplicate = data[data.duplicated()]
print(len(duplicate))
# Out:
# 37

# %%
# dropping duplicates, then check again to make sure
data = data.drop_duplicates()
duplicate = data[data.duplicated()]
display(duplicate)
print(len(duplicate))
# Out:
# Empty DataFrame
# Columns: [customer, state, customer lifetime value, response, coverage, education, effective to date, employment status, gender, income, location code, marital status, monthly premium auto, months since last claim, months since policy inception, number of open complaints, number of policies, policy type, policy, renew offer type, sales channel, total claim amount, vehicle class, vehicle size, vehicle type]
# Index: []
# 0

# %%
# checking whether the nan are in the same row: response and state
# prints False if the rows dont match. prints nothing if the rows match

#saving index of the nan values to a variable
# the variables will then be matched
na_claim = data[data['months since last claim'].isnull()].index.tolist()
na_complaints = data[data['number of open complaints'].isnull()].index.tolist()
for i in range(631):
    if na_claim[i] != na_complaints[i]:
        print(False)

# %%
# quick numerical analysis
display(data[["months since last claim","number of open complaints"]].describe())
display(data[["months since last claim","number of open complaints"]].mode())
# Out:
#        months since last claim  number of open complaints
# count             10277.000000               10277.000000
# mean                 15.149071                   0.384256
# std                  10.080349                   0.912457
# min                   0.000000                   0.000000
# 25%                   6.000000                   0.000000
# 50%                  14.000000                   0.000000
# 75%                  23.000000                   0.000000
# max                  35.000000                   5.000000
#    months since last claim  number of open complaints
# 0                      3.0                        0.0

# %%
display(data["months since last claim"].value_counts(dropna=False))
display(data["number of open complaints"].value_counts(dropna=False))
# Out:
# NaN     633
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 19.0    276
# 23.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: months since last claim, dtype: int64
# 0.0    8160
# 1.0    1145
# NaN     633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %%
data.isna().sum()
# Out:
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employment status                   0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           582
# months since policy inception       0
# number of open complaints         582
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     579
# vehicle size                      579
# vehicle type                     5157
# dtype: int64

# %% [markdown]
# ### checking rows

# %%
na_claim = data[data['months since last claim'].isnull()].index.tolist()
na_complaints = data[data['number of open complaints'].isnull()].index.tolist()
for i in range(582):
    if na_claim[i] == na_complaints[i]:
        print(True)
    else:
        print(False)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
na_vehicle_class = data[data['vehicle class'].isnull()].index.tolist()
na_vehicle_size = data[data['vehicle size'].isnull()].index.tolist()
for i in range(579):
    if na_vehicle_class[i] == na_vehicle_size[i]:
        print(True)
    else:
        print(False)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
data["months since last claim"].value_counts(dropna=False)
# Out:
# NaN     582
# 3.0     401
# 6.0     381
# 1.0     364
# 7.0     354
# 4.0     353
# 2.0     348
# 5.0     331
# 0.0     329
# 10.0    323
# 16.0    318
# 11.0    316
# 15.0    303
# 8.0     297
# 13.0    295
# 12.0    289
# 17.0    283
# 14.0    280
# 19.0    263
# 9.0     263
# 23.0    261
# 25.0    253
# 21.0    250
# 20.0    246
# 18.0    244
# 22.0    231
# 29.0    222
# 24.0    221
# 28.0    209
# 26.0    202
# 31.0    201
# 27.0    193
# 30.0    192
# 33.0    188
# 34.0    185
# 35.0    148
# 32.0    140
# Name: months since last claim, dtype: int64

# %%
data = data0
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employment status gender  income  \
# 0       College           2/18/11          Employed      M   48029
# 1       College           1/18/11        Unemployed      F       0
# 2      Bachelor           2/10/11          Employed      M   22139
# 3       College           1/11/11          Employed      M   49078
# 4      Bachelor           1/17/11     Medical Leave      F   23675
# ...         ...               ...               ...    ...     ...
# 10905  Bachelor           1/19/11        Unemployed      F       0
# 10906   College            1/6/11          Employed      F   61146
# 10907  Bachelor            2/6/11          Employed      F   39837
# 10908   College           2/13/11          Employed      F   64195
# 10909  Bachelor            1/8/11        Unemployed      M       0
#
#       location code marital status  monthly premium auto  \
# 0          Suburban        Married                    61
# 1          Suburban         Single                    64
# 2          Suburban         Single                   100
# 3          Suburban         Single                    97
# 4          Suburban        Married                   117
# ...             ...            ...                   ...
# 10905      Suburban        Married                   253
# 10906         Urban        Married                    65
# 10907         Rural        Married                   201
# 10908         Urban       Divorced                   158
# 10909      Suburban         Single                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        number of open complaints  number of policies     policy type  \
# 0                            0.0                   9  Corporate Auto
# 1                            0.0                   1   Personal Auto
# 2                            0.0                   2   Personal Auto
# 3                            0.0                   2  Corporate Auto
# 4                            NaN                   7   Personal Auto
# ...                          ...                 ...             ...
# 10905                        NaN                   7   Personal Auto
# 10906                        0.0                   6   Personal Auto
# 10907                        0.0                   2  Corporate Auto
# 10908                        4.0                   6   Personal Auto
# 10909                        0.0                   3   Personal Auto
#
#              policy renew offer type sales channel  total claim amount  \
# 0      Corporate L3           Offer3         Agent          292.800000
# 1       Personal L3           Offer4   Call Center          744.924331
# 2       Personal L3           Offer3   Call Center          480.000000
# 3      Corporate L3           Offer2        Branch          484.013411
# 4       Personal L2           Offer1        Branch          707.925645
# ...             ...              ...           ...                 ...
# 10905   Personal L1           Offer3           Web         1214.400000
# 10906   Personal L3           Offer2        Branch          273.018929
# 10907  Corporate L3           Offer1           Web          381.306996
# 10908   Personal L1           Offer1        Branch          618.288849
# 10909   Personal L1           Offer4           Web         1021.719397
#
#        vehicle class vehicle size vehicle type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 25 columns]

# %%
data.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employment status                   0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# dtype: int64

# %% [markdown]
# ### deleting duplicates

# %%
duplicate = data[data.duplicated()]
display(duplicate)
print(len(duplicate))
data = data.drop_duplicates()
duplicate = data[data.duplicated()]
display(duplicate)
print(len(duplicate))
# Out:
#       customer       state  customer lifetime value response  coverage  \
#
# 10276                     29.0                             49
# 10499                      NaN                             86
#
#        number of open complaints  number of policies     policy type  \
# 1134                         0.0                   2   Personal Auto
# 2799                         0.0                   9   Personal Auto
# 2805                         0.0                   5   Personal Auto
# 3590                         0.0                   1  Corporate Auto
# 3877                         0.0                   7   Personal Auto
# 4581                         NaN                   9   Personal Auto
# 4992                         NaN                   2  Corporate Auto
# 5734                         0.0                   1   Personal Auto
# 5863                         NaN                   2   Personal Auto
# 6068                         0.0                   9  Corporate Auto
# 6091                         1.0                   9   Personal Auto
# 6116                         0.0                   2   Personal Auto
# 6117                         5.0                   1   Personal Auto
# 6315                         0.0                   1   Personal Auto
# 6410                         0.0                   1   Personal Auto
# 6578                         NaN                   2  Corporate Auto
# 6699                         3.0                   2  Corporate Auto
# 6743                         NaN                   9   Personal Auto
# 6879                         NaN                   2   Personal Auto
# 7533                         3.0                   2  Corporate Auto
# 7764                         0.0                   7   Personal Auto
# 7786                         0.0                   3   Personal Auto
# 7796                         1.0                   1   Personal Auto
# 8509                         0.0                   7   Personal Auto
# 8531                         0.0                   4  Corporate Auto
# 8680                         1.0                   6   Personal Auto
# 8827                         3.0                   2  Corporate Auto
# 8847                         0.0                   1  Corporate Auto
# 8891                         NaN                   1   Personal Auto
# 8926                         NaN                   3   Personal Auto
# 9095                         0.0                   4  Corporate Auto
# 9313                         0.0                   2   Personal Auto
# 9432                         NaN                   4   Personal Auto
# 9943                         0.0                   2   Personal Auto
# 10006                        0.0                   1   Personal Auto
# 10276                        1.0                   1   Personal Auto
# 10499                        NaN                   2  Corporate Auto
#
#              policy renew offer type sales channel  total claim amount  \
# 1134    Personal L2           Offer4   Call Center          219.209762
# 2799    Personal L1           Offer1   Call Center          428.734656
# 2805    Personal L3           Offer3           Web          331.200000
# 3590   Corporate L3           Offer1   Call Center          199.551735
# 3877    Personal L3           Offer1        Branch          379.200000
# 4581    Personal L2           Offer1           Web          365.835977
# 4992   Corporate L3           Offer1        Branch          523.815839
# 5734    Personal L2           Offer2        Branch          777.600000
# 5863    Personal L1           Offer3         Agent          151.843731
# 6068   Corporate L3           Offer3           Web          272.649844
# 6091    Personal L2           Offer1           Web          365.835977
# 6116    Personal L3           Offer1        Branch          340.201412
# 6117    Personal L2           Offer2           Web          238.530745
# 6315    Personal L3           Offer2   Call Center          199.851201
# 6410    Personal L3           Offer2           Web          292.800000
# 6578   Corporate L3           Offer1   Call Center          192.085299
# 6699   Corporate L1           Offer3         Agent          162.775889
# 6743    Personal L2           Offer1           Web          365.835977
# 6879    Personal L3           Offer1        Branch          316.800000
# 7533   Corporate L3           Offer3         Agent          336.000000
# 7764    Personal L3           Offer3        Branch          326.400000
# 7786    Personal L2           Offer2   Call Center          345.600000
# 7796    Personal L2           Offer4   Call Center          340.800000
# 8509    Personal L2           Offer3         Agent          257.090387
# 8531   Corporate L2           Offer2         Agent          432.000000
# 8680    Personal L2           Offer2         Agent          842.400000
# 8827   Corporate L3           Offer3         Agent          336.000000
# 8847   Corporate L3           Offer3        Branch          331.200000
# 8891    Personal L3           Offer2         Agent          784.186389
# 8926    Personal L3           Offer2           Web          740.963933
# 9095   Corporate L1           Offer2         Agent          400.181882
# 9313    Personal L2           Offer1           Web         1605.600000
# 9432    Personal L1           Offer1         Agent          566.400000
# 9943    Personal L2           Offer3   Call Center          504.365927
# 10006   Personal L2           Offer2   Call Center          350.400000
# 10276   Personal L3           Offer3        Branch          321.600000
# 10499  Corporate L3           Offer2        Branch          987.122788
#
#        vehicle class vehicle size vehicle type
# 1134   Four-Door Car      Medsize            A
# 2799   Four-Door Car        Small            A
# 2805    Two-Door Car      Medsize            A
# 3590    Two-Door Car      Medsize          NaN
# 3877             NaN          NaN            A
# 4581             NaN          NaN          NaN
# 4992             SUV      Medsize          NaN
# 5734             NaN          NaN          NaN
# 5863    Two-Door Car      Medsize            A
# 6068   Four-Door Car      Medsize          NaN
# 6091             NaN          NaN            A
# 6116   Four-Door Car      Medsize          NaN
# 6117   Four-Door Car      Medsize            A
# 6315   Four-Door Car      Medsize            A
# 6410   Four-Door Car      Medsize          NaN
# 6578      Sports Car      Medsize            A
# 6699             NaN          NaN            A
# 6743             NaN          NaN          NaN
# 6879    Two-Door Car      Medsize            A
# 7533    Two-Door Car      Medsize          NaN
# 7764             NaN          NaN          NaN
# 7786   Four-Door Car      Medsize          NaN
# 7796   Four-Door Car      Medsize          NaN
# 8509             NaN          NaN          NaN
# 8531             NaN          NaN            A
# 8680             NaN          NaN            A
# 8827    Two-Door Car      Medsize          NaN
# 8847   Four-Door Car        Small            A
# 8891   Four-Door Car        Large            A
# 8926             SUV        Small            A
# 9095      Sports Car      Medsize          NaN
# 9313             NaN          NaN            A
# 9432             SUV      Medsize          NaN
# 9943             NaN          NaN            A
# 10006            NaN          NaN            A
# 10276            NaN          NaN          NaN
# 10499  Four-Door Car        Small            A
# 37
# Empty DataFrame
# Columns: [customer, state, customer lifetime value, response, coverage, education, effective to date, employment status, gender, income, location code, marital status, monthly premium auto, months since last claim, months since policy inception, number of open complaints, number of policies, policy type, policy, renew offer type, sales channel, total claim amount, vehicle class, vehicle size, vehicle type]
# Index: []
# 0

# %%
data.isna().sum()
# Out:
# customer                            0
# state                             614
# customer lifetime value             0
# response                          614
# coverage                            0
# education                           0
# effective to date                   0
# employment status                   0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           623
# months since policy inception       0
# number of open complaints         623
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     608
# vehicle size                      608
# vehicle type                     5465
# dtype: int64

# %%
data

# %%
#data1['state'] = data1['state'].fillna('CA')

# %%
# restore the dropped NaN values (rows) from state and response
# replace NaN in state with most frequent state
# replace NaN in response with ??? (median)

# replace NaN in months since last claim with the average of that column
# replace NaN in number of open complaints with 0.0 (the median)

# %%
#data1['state'] = data1['state'].fillna('CA')
